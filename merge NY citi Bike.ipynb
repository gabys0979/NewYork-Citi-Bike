# %%
import pandas as pd
import os

from datetime import datetime

# %%
files = ['C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202207-citibike-tripdata.csv', 
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202208-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202209-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202210-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202211-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202212-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202301-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202302-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202304-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202305-citibike-tripdata.csv',
           'C:\\Users\\dogpl\\bootcamp\\NY Bike\\citibike-data\\JC-202306-citibike-tripdata.csv']


# Create an empty list to store each dataframe
city_df_list = []

# Loop through each file and read it into a dataframe
for file in files:
    city_df = pd.read_csv(file)
    city_df_list.append(city_df)
    
# Concatenate all dataframes into one
city_df = pd.concat(city_df_list)

# Show dataframe
city_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      89CDCE3224502904   classic_bike  2022-07-21 18:19:45
# 1      3E6E50F51BD4CBD9  electric_bike  2022-07-21 17:50:57
# 2      8A9058FAA9115562  electric_bike  2022-07-23 11:51:55
# 3      C566A187663748AE   classic_bike  2022-07-30 20:34:40
# 4      7E754D57276BE57E   classic_bike  2022-07-14 18:42:34
# ...                 ...            ...                  ...
# 97018  2C69F8EF2A1BDD90   classic_bike  2023-06-30 19:41:00
# 97019  43E592256BC287BB   classic_bike  2023-06-20 18:55:02
# 97020  4C3A7521689C560C  electric_bike  2023-06-22 19:24:22
# 97021  9AAA8F2E630456E7   classic_bike  2023-06-30 13:34:09
# 97022  064CE90800E9C21F   classic_bike  2023-06-13 17:23:31
#
#                   ended_at             start_station_name start_station_id  \
# 0      2022-07-21 18:28:21             Marshall St & 2 St            HB408
# 1      2022-07-21 17:59:17             Marshall St & 2 St            HB408
# ...

# %%
city_df.to_csv("citibike-data/citibike-2022-2023.csv")
